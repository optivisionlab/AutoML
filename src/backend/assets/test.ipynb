# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv("/home/vananh/Homeworks/python/HAutoML/AutoML/src/backend/assets/online_shoppers/online_shoppers_intention.csv")

df_train, df_test = train_test_split(
        df, test_size=0.2, random_state=4100000, shuffle=True
    )

# %%
df_train.to_csv("/home/vananh/Homeworks/python/HAutoML/AutoML/src/backend/assets/online_shoppers/online_shoppers_intention_train.csv", index=False)
df_test.to_csv("/home/vananh/Homeworks/python/HAutoML/AutoML/src/backend/assets/online_shoppers/online_shoppers_intention_test.csv", index=False)
